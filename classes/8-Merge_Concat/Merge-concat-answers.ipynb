# %% [markdown]
# ## Merge and Concatenate

# %% [markdown]
# #### Merging basics

# %%
import pandas as pd

# %%
pops = pd.DataFrame({'Country Code': ['THA', 'USA', 'NLD', 'GER'],
                     'Population': [68, 328, 17, 82]})

capitals = pd.DataFrame({'Country Code': ['THA', 'USA', 'NLD', 'GER', 'JPN'],
                         'Country Name': ['Thailand', 'United States', 'Netherlands', 'Germany', 'Japan'],
                         'Capital Name': ['Bangkok', 'Washington D.C.', 'Amsterdam', 'Berlin', 'Tokyo']})
display(pops, capitals)
# Out:
#   Country Code  Population
# 0          THA          68
# 1          USA         328
# 2          NLD          17
# 3          GER          82
#   Country Code   Country Name     Capital Name
# 0          THA       Thailand          Bangkok
# 1          USA  United States  Washington D.C.
# 2          NLD    Netherlands        Amsterdam
# 3          GER        Germany           Berlin
# 4          JPN          Japan            Tokyo

# %%
# merge example - inner join
pd.merge(capitals, pops, 
         on='Country Code', how='inner')
# Out:
#   Country Code   Country Name     Capital Name  Population
# 0          THA       Thailand          Bangkok          68
# 1          USA  United States  Washington D.C.         328
# 2          NLD    Netherlands        Amsterdam          17
# 3          GER        Germany           Berlin          82

# %%
# merge example - outer join
pd.merge(capitals, pops, 
         on='Country Code', how='outer')
# Out:
#   Country Code   Country Name     Capital Name  Population
# 0          THA       Thailand          Bangkok        68.0
# 1          USA  United States  Washington D.C.       328.0
# 2          NLD    Netherlands        Amsterdam        17.0
# 3          GER        Germany           Berlin        82.0
# 4          JPN          Japan            Tokyo         NaN

# %%
# merge example - left join
pd.merge(capitals, pops, 
         on='Country Code', how='left')
# Out:
#   Country Code   Country Name     Capital Name  Population
# 0          THA       Thailand          Bangkok        68.0
# 1          USA  United States  Washington D.C.       328.0
# 2          NLD    Netherlands        Amsterdam        17.0
# 3          GER        Germany           Berlin        82.0
# 4          JPN          Japan            Tokyo         NaN

# %%
# merge example - right join
pd.merge(capitals, pops, 
         on='Country Code', how='right')
# Out:
#   Country Code   Country Name     Capital Name  Population
# 0          THA       Thailand          Bangkok          68
# 1          USA  United States  Washington D.C.         328
# 2          NLD    Netherlands        Amsterdam          17
# 3          GER        Germany           Berlin          82

# %% [markdown]
# #### Concatenate basics

# %%
pops2 = pd.DataFrame({'Country Code': ['KOR', 'AFG', 'AUT'],
          'Population': [8, 29, 8]})
display(pops2)
# Out:
#   Country Code  Population
# 0          KOR           8
# 1          AFG          29
# 2          AUT           8

# %%
# pops first
pd.concat([pops, pops2], axis=0).reset_index(drop=True)
# Out:
#   Country Code  Population
# 0          THA          68
# 1          USA         328
# 2          NLD          17
# 3          GER          82
# 4          KOR           8
# 5          AFG          29
# 6          AUT           8

# %%
# pops second
pd.concat([pops2, pops])
# Out:
#   Country Code  Population
# 0          KOR           8
# 1          AFG          29
# 2          AUT           8
# 0          THA          68
# 1          USA         328
# 2          NLD          17
# 3          GER          82

# %%
# append
pops = pops.append(pops2)
pops.reset_index(drop=True)
# Out:
#   Country Code  Population
# 0          THA          68
# 1          USA         328
# 2          NLD          17
# 3          GER          82
# 4          KOR           8
# 5          AFG          29
# 6          AUT           8

# %% [markdown]
# #### Mapping tables example: Toys dataset

# %%
products = pd.read_csv('../datasets/toys/products.csv')
stores = pd.read_csv('../datasets/toys/stores.csv')
sales = pd.read_csv('../datasets/toys/sales.csv')
inventory = pd.read_csv('../datasets/toys/inventory.csv')

print('Products: ', products.shape)
print('Stores: ', stores.shape)
print('Sales: ', sales.shape)
print('Inventory: ', inventory.shape)
# Out:
# Products:  (35, 5)
# Stores:  (50, 5)
# Sales:  (829262, 5)
# Inventory:  (1593, 3)

# %%
products.head(3)
# Out:
#    Product_ID     Product_Name Product_Category Product_Cost Product_Price
# 0           1    Action Figure             Toys       $9.99        $15.99
# 1           2   Animal Figures             Toys       $9.99        $12.99
# 2           3  Barrel O' Slime     Art & Crafts       $1.99         $3.99

# %%
stores.head(3)
# Out:
#    Store_ID                Store_Name   Store_City Store_Location  \
# 0         1  Maven Toys Guadalajara 1  Guadalajara    Residential
# 1         2    Maven Toys Monterrey 1    Monterrey    Residential
# 2         3  Maven Toys Guadalajara 2  Guadalajara     Commercial
#
#   Store_Open_Date
# 0      1992-09-18
# 1      1995-04-27
# 2      1999-12-27

# %%
sales.head(3)
# Out:
#    Sale_ID        Date  Store_ID  Product_ID  Units
# 0        1  2017-01-01        24           4      1
# 1        2  2017-01-01        28           1      1
# 2        3  2017-01-01         6           8      1

# %%
inventory.head(3)
# Out:
#    Store_ID  Product_ID  Stock_On_Hand
# 0         1           1             27
# 1         1           2              0
# 2         1           3             32

# %%
# map store names using store id
mapped = pd.merge(sales, stores[['Store_ID', 'Store_Name', 'Store_Location']],
                  on='Store_ID', how='left')
mapped.head(3)
# Out:
#    Sale_ID        Date  Store_ID  Product_ID  Units  \
# 0        1  2017-01-01        24           4      1
# 1        2  2017-01-01        28           1      1
# 2        3  2017-01-01         6           8      1
#
#                     Store_Name Store_Location
# 0  Maven Toys Aguascalientes 1       Downtown
# 1          Maven Toys Puebla 2       Downtown
# 2        Maven Toys Mexicali 1     Commercial

# %%
# map product names and prices using product id 
mapped2 = pd.merge(mapped, products[['Product_ID', 'Product_Name', 'Product_Price']],
                   on='Product_ID', how='left')
mapped2.head(3)
# Out:
#    Sale_ID        Date  Store_ID  Product_ID  Units  \
# 0        1  2017-01-01        24           4      1
# 1        2  2017-01-01        28           1      1
# 2        3  2017-01-01         6           8      1
#
#                     Store_Name Store_Location      Product_Name Product_Price
# 0  Maven Toys Aguascalientes 1       Downtown  Chutes & Ladders       $12.99
# 1          Maven Toys Puebla 2       Downtown     Action Figure       $15.99
# 2        Maven Toys Mexicali 1     Commercial     Deck Of Cards        $6.99

# %%
mapped2['Product_Price'] = mapped2['Product_Price'].str.replace("$","").astype(float)
mapped2['Sales_Amount'] = mapped2['Units']*mapped2['Product_Price']

# %%
mapped2[mapped2['Units']>1].head(10)
# Out:
#     Sale_ID        Date  Store_ID  Product_ID  Units  \
# 12       13  2017-01-01        37           8      2
# 19       20  2017-01-01         3          24      2
# 29       30  2017-01-01        34          18      3
# 34       35  2017-01-01        39          34      3
# 37       38  2017-01-01        32           8      4
# 44       45  2017-01-01        41           8      3
# 46       47  2017-01-01        30           1      3
# 55       56  2017-01-01        41           8      2
# 63       64  2017-01-01        34          18      2
# 71       72  2017-01-01        19           6      2
#
#                        Store_Name Store_Location   Product_Name  \
# 12  Maven Toys Ciudad de Mexico 3    Residential  Deck Of Cards
# 19       Maven Toys Guadalajara 2     Commercial       Nerf Gun
# 29      Maven Toys Villahermosa 1       Downtown    Lego Bricks
# 34            Maven Toys Xalapa 2       Downtown      Toy Robot
# 37        Maven Toys Hermosillo 1    Residential  Deck Of Cards
# 44        Maven Toys Hermosillo 2       Downtown  Deck Of Cards
# 46       Maven Toys Guadalajara 3        Airport  Action Figure
# 55        Maven Toys Hermosillo 2       Downtown  Deck Of Cards
# 63      Maven Toys Villahermosa 1       Downtown    Lego Bricks
# 71            Maven Toys Puebla 1     Commercial      Colorbuds
#
#     Product_Price  Sales_Amount
# 12           6.99         13.98
# 19          19.99         39.98
# 29          39.99        119.97
# 34          25.99         77.97
# 37           6.99         27.96
# 44           6.99         20.97
# 46          15.99         47.97
# 55           6.99         13.98
# 63          39.99         79.98
# 71          14.99         29.98

# %%
# filter date to be oct 1, 2018
oct_sales = mapped2[mapped2['Date']=='2018-09-30']
oct_sales.shape
# Out:
# (2010, 10)

# %%
# aggregate sales
oct_sales_sum = oct_sales.groupby(['Store_ID', 'Product_ID']).Units.sum().reset_index()
oct_sales_sum.head()
# Out:
#    Store_ID  Product_ID  Units
# 0         1           5      5
# 1         1           9     35
# 2         1          12      4
# 3         1          19      3
# 4         1          24      4

# %%
# map inventory
oct_inv = pd.merge(oct_sales_sum, inventory,
                   on=['Store_ID', 'Product_ID'], 
                   how='left')
oct_inv.tail()
# Out:
#      Store_ID  Product_ID  Units  Stock_On_Hand
# 198        49           3     20             14
# 199        49          10      3             36
# 200        49          24      8             23
# 201        49          25      4             23
# 202        49          30      2              3

# %%
oct_inv['Stock_Gap'] = oct_inv['Stock_On_Hand'] - oct_inv['Units']
oct_inv['Stock_Gap'].describe()
# Out:
# count    203.000000
# mean       6.714286
# std       24.014376
# min      -67.000000
# 25%       -6.000000
# 50%        3.000000
# 75%       17.000000
# max       98.000000
# Name: Stock_Gap, dtype: float64
