# %% [markdown]
# ## Groupping and Aggregation

# %%
# import
import pandas as pd

# %%
# dataset
walt = pd.read_csv('../datasets/WALMART_SALES_DATA.csv')

# %%
walt
# Out:
#       Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1  05-02-2010    1643690.90             0        42.31       2.572
# 1         1  12-02-2010    1641957.44             1        38.51       2.548
# 2         1  19-02-2010    1611968.17             0        39.93       2.514
# 3         1  26-02-2010    1409727.59             0        46.63       2.561
# 4         1  05-03-2010    1554806.68             0        46.50       2.625
# ...     ...         ...           ...           ...          ...         ...
# 6430     45  28-09-2012     713173.95             0        64.88       3.997
# 6431     45  05-10-2012     733455.07             0        64.89       3.985
# 6432     45  12-10-2012     734464.36             0        54.47       4.000
# 6433     45  19-10-2012     718125.53             0        56.47       3.969
# 6434     45  26-10-2012     760281.43             0        58.85       3.882
#
#              CPI  Unemployment
# 0     211.096358         8.106
# 1     211.242170         8.106
# 2     211.289143         8.106
# 3     211.319643         8.106
# 4     211.350143         8.106
# ...          ...           ...
# 6430  192.013558         8.684
# 6431  192.170412         8.667
# 6432  192.327265         8.667
# 6433  192.330854         8.667
# 6434  192.308899         8.667
#
# [6435 rows x 8 columns]

# %% [markdown]
# #### Aggregation functions

# %%
walt['Weekly_Sales'].describe()
# Out:
# count    6.435000e+03
# mean     1.046965e+06
# std      5.643666e+05
# min      2.099862e+05
# 25%      5.533501e+05
# 50%      9.607460e+05
# 75%      1.420159e+06
# max      3.818686e+06
# Name: Weekly_Sales, dtype: float64

# %%
# aggregate weekly sales
# sum
print(walt['Weekly_Sales'].sum())

# max
print(walt['Weekly_Sales'].max())

# mean 
print(walt['Weekly_Sales'].mean())
# Out:
# 6737218987.11
# 3818686.45
# 1046964.8775617732

# %%
# holiday_flag - count holiday
print(walt['Holiday_Flag'].sum())
# Out:
# 450

# %%
# holiday_flag - count
print(walt['Date'].count())
print(walt['Date'].nunique())
# Out:
# 6435
# 143

# %% [markdown]
# #### Groupping

# %%
# base case: how to do groupping
sum_byWk = walt.groupby('Date').Weekly_Sales.sum().reset_index()
sum_byWk.head()
# Out:
#          Date  Weekly_Sales
# 0  01-04-2011   43458991.19
# 1  01-06-2012   48281649.72
# 2  01-07-2011   47578519.50
# 3  01-10-2010   42239875.87
# 4  02-03-2012   46861034.97

# %%
# base case: how to do groupping
sum_byWk = walt.groupby('Date').Weekly_Sales.mean().reset_index()
sum_byWk.head()
# Out:
#          Date  Weekly_Sales
# 0  01-04-2011  9.657554e+05
# 1  01-06-2012  1.072926e+06
# 2  01-07-2011  1.057300e+06
# 3  01-10-2010  9.386639e+05
# 4  02-03-2012  1.041356e+06

# %%
import numpy as np
# two aggregation functions
sum_byWk = walt.groupby('Date').Weekly_Sales.agg([sum, np.mean, max, min]).reset_index()
sum_byWk.head()
# Out:
#          Date          sum          mean         max        min
# 0  01-04-2011  43458991.19  9.657554e+05  1927993.09  232769.09
# 1  01-06-2012  48281649.72  1.072926e+06  2179360.94  261131.09
# 2  01-07-2011  47578519.50  1.057300e+06  2074668.19  226702.36
# 3  01-10-2010  42239875.87  9.386639e+05  1933719.21  224294.39
# 4  02-03-2012  46861034.97  1.041356e+06  2206319.90  248051.53

# %%
# base case: how to do groupping
sum_byWk = walt.groupby(['Holiday_Flag', 'Date']).Weekly_Sales.agg([sum, np.mean, max, min]).reset_index()
sum_byWk
# Out:
#      Holiday_Flag        Date          sum          mean         max  \
# 0               0  01-04-2011  43458991.19  9.657554e+05  1927993.09
# 1               0  01-06-2012  48281649.72  1.072926e+06  2179360.94
# 2               0  01-07-2011  47578519.50  1.057300e+06  2074668.19
# 3               0  01-10-2010  42239875.87  9.386639e+05  1933719.21
# 4               0  02-03-2012  46861034.97  1.041356e+06  2206319.90
# ..            ...         ...          ...           ...         ...
# 138             1  12-02-2010  48336677.63  1.074148e+06  2188307.39
# 139             1  25-11-2011  66593605.26  1.479858e+06  3004702.33
# 140             1  26-11-2010  65821003.24  1.462689e+06  2939946.38
# 141             1  30-12-2011  46042461.04  1.023166e+06  2043245.00
# 142             1  31-12-2010  40432519.00  8.985004e+05  1799737.79
#
#            min
# 0    232769.09
# 1    261131.09
# 2    226702.36
# 3    224294.39
# 4    248051.53
# ..         ...
# 138  286857.13
# 139  255996.47
# 140  240044.57
# 141  215359.21
# 142  219804.85
#
# [143 rows x 6 columns]

# %%
# base case: how to do groupping
sum_byWk = walt.groupby('Holiday_Flag').Weekly_Sales.agg([sum, np.mean, max, min]).reset_index()
sum_byWk
# Out:
#    Holiday_Flag           sum          mean         max        min
# 0             0  6.231919e+09  1.041256e+06  3818686.45  209986.25
# 1             1  5.052996e+08  1.122888e+06  3004702.33  215359.21

# %%
# which store has the highest total sales
sum_byWk = walt.groupby('Store').Weekly_Sales.agg([sum, np.mean, max, min]).reset_index()
sum_byWk.sort_values(by='sum').head()
# Out:
#     Store          sum           mean        max        min
# 32     33  37160221.96  259861.692028  331173.51  209986.25
# 43     44  43293087.84  302748.866014  376233.89  241937.11
# 4       5  45475688.90  318011.810490  507900.07  260636.71
# 35     36  53412214.97  373511.992797  489372.02  270677.98
# 37     38  55159626.42  385731.653287  499267.66  303908.81

# %%
# which store has the highest average sales
sum_byWk = walt.groupby('Store').Weekly_Sales.agg([sum, np.mean, max, min]).reset_index()
sum_byWk.sort_values(by='max', ascending=False).head()
# Out:
#     Store           sum          mean         max         min
# 13     14  2.889999e+08  2.020978e+06  3818686.45  1479514.66
# 19     20  3.013978e+08  2.107677e+06  3766687.43  1761016.51
# 9      10  2.716177e+08  1.899425e+06  3749057.69  1627707.31
# 3       4  2.995440e+08  2.094713e+06  3676388.98  1762539.30
# 12     13  2.865177e+08  2.003620e+06  3595903.20  1633663.12

# %%
# which store has the highest average sales
sum_byWk = walt.groupby('Store').Weekly_Sales.agg([sum, np.mean, max, min]).reset_index()
sum_byWk.sort_values(by='max', ascending=False).head()
# Out:
#     Store           sum          mean         max         min
# 13     14  2.889999e+08  2.020978e+06  3818686.45  1479514.66
# 19     20  3.013978e+08  2.107677e+06  3766687.43  1761016.51
# 9      10  2.716177e+08  1.899425e+06  3749057.69  1627707.31
# 3       4  2.995440e+08  2.094713e+06  3676388.98  1762539.30
# 12     13  2.865177e+08  2.003620e+06  3595903.20  1633663.12

# %% [markdown]
# #### Example Usage: Rolling Average

# %%
#walt['Weekly_Sales'].rolling(3).mean()
R3M = walt.groupby('Store').rolling(3, min_periods=0).Weekly_Sales.mean().reset_index(drop=True)

# %%
walt['R3M'] = R3M
walt['R3M'].head()
# Out:
# 0    1.643691e+06
# 1    1.642824e+06
# 2    1.632539e+06
# 3    1.554551e+06
# 4    1.525501e+06
# Name: R3M, dtype: float64

# %%
walt[walt['Store']==45].head()
# Out:
#       Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 6292     45  05-02-2010     890689.51             0        27.31       2.784
# 6293     45  12-02-2010     656988.64             1        27.73       2.773
# 6294     45  19-02-2010     841264.04             0        31.27       2.745
# 6295     45  26-02-2010     741891.65             0        34.89       2.754
# 6296     45  05-03-2010     777951.22             0        37.13       2.777
#
#              CPI  Unemployment            R3M
# 6292  181.871190         8.992  890689.510000
# 6293  181.982317         8.992  773839.075000
# 6294  182.034782         8.992  796314.063333
# 6295  182.077469         8.992  746714.776667
# 6296  182.120157         8.992  787035.636667

# %%
walt.isnull().sum()
# Out:
# Store           0
# Date            0
# Weekly_Sales    0
# Holiday_Flag    0
# Temperature     0
# Fuel_Price      0
# CPI             0
# Unemployment    0
# R3M             0
# dtype: int64

# %%
walt['R3M'] = walt['R3M'].fillna(0)
walt.isnull().sum()
# Out:
# Store           0
# Date            0
# Weekly_Sales    0
# Holiday_Flag    0
# Temperature     0
# Fuel_Price      0
# CPI             0
# Unemployment    0
# R3M             0
# dtype: int64
